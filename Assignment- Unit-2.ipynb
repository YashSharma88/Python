# %%
print("""Que-1. Write a python Program to print the following string in a specific format.

Input :- Twinkle-Twiinkle, little star, How I wonder What you are!, Up above the world so high, Like a diamond in the sky, Twinkle-Twinkle Little star, How I wonder what you are.

Output :-Twinkle-Twiinkle, little star,
         How I wonder What you are!,
         Up above the world so high,
         Like a diamond in the sky,
         Twinkle-Twinkle Little star,
         How I wonder what you are.

Sol'n : # Use \n = Next Line (For use next line)

         Twinkle-Twiinkle, little star,
         How I wonder What you are!,
         Up above the world so high,
         Like a diamond in the sky,
         Twinkle-Twinkle Little star,
         How I wonder what you are.
""")
# Out:
# Que-1. Write a python Program to print the following string in a specific format.
#
# Input :- Twinkle-Twiinkle, little star, How I wonder What you are!, Up above the world so high, Like a diamond in the sky, Twinkle-Twinkle Little star, How I wonder what you are.
#
# Output :-Twinkle-Twiinkle, little star,
#          How I wonder What you are!,
#          Up above the world so high,
#          Like a diamond in the sky,
#          Twinkle-Twinkle Little star,
#          How I wonder what you are.
#
# Sol'n : # Use
#  = Next Line (For use next line)
#
#          Twinkle-Twiinkle, little star,
#          How I wonder What you are!,
#          Up above the world so high,
#          Like a diamond in the sky,
#          Twinkle-Twinkle Little star,
#          How I wonder what you are.

# %%
print("Twinkle-Twiinkle, little star,\nHow I wonder What you are!,\nUp above the world so high,\nLike a diamond in the sky,\nTwinkle-Twinkle Little star,\nHow I wonder what you are.")
# Out:
# Twinkle-Twiinkle, little star,
# How I wonder What you are!,
# Up above the world so high,
# Like a diamond in the sky,
# Twinkle-Twinkle Little star,
# How I wonder what you are.

# %%
print("""Que-2. Write a python program that calculates the area of a circle based on the radius 10 cm, 12 cm, 25.67 cm.
Sol'n : a=10
        Formula : Area of circle = Pie*r*r / Pie(⫪)*r^2 [Pie(⫪) = 22/7 or 3.14]
        print("The area of the circle is with 10 cm radius is", 3.14*(a**2), "cm")
        b=12
        print("The area of the circle is with 12 cm radius is", 3.14*(b**2), "cm")
        c=25.67
        print("The area of the circle is with 25.67 cm radius is", 3.14*(c**2), "cm
""")
# Out:
# Que-2. Write a python program that calculates the area of a circle based on the radius 10 cm, 12 cm, 25.67 cm.
# Sol'n : a=10
#         Formula : Area of circle = Pie*r*r / Pie*r^2 [Pie = 22/7 or 3.14]
#         print("The area of the circle is with 10 cm radius is", 3.14*(a**2) "cm")
#         b=12
#         print("The area of the circle is with 12 cm radius is", 3.14*(b**2) "cm")
#         c=25.67
#         print("The area of the circle is with 25.67 cm radius is", 3.14*(c**2) "cm")

# %%
a=10
print("The area of the circle is with 10 cm radius is", 3.14*(a**2), "cm")
b=12
print("The area of the circle is with 12 cm radius is", 3.14*(b**2), "cm")
c=25.67
print("The area of the circle is with 25.67 cm radius is", 3.14*(c**2), "cm")
# Out:
# The area of the circle is with 10 cm radius is 314.0 cm
# The area of the circle is with 12 cm radius is 452.16 cm
# The area of the circle is with 25.67 cm radius is 2069.0995460000004 cm

# %%
print("""Que-3. Write a python program to get the volume of a sphere with radius 6.
Sol'n : # Volume of sphere is = 4/3*Pie(⫪)*radius(r^3) / 4/3*⫪*r*r*r
            r=6
            print(4/3*3.14*(6**3)
            904.319999.. Answer
""")
# Out:
# Que-3. Write a python program to get the volume of a sphere with radius 6.
# Sol'n : # Volume of sphere is = 4/3*Pie(⫪)*radius(r^3) / 4/3*⫪*r*r*r
#             r=6
#             print(4/3*3.14*(6**3)
#             904.319999.. Answer

# %%
r=6
# Formula = 4/3*⫪(3.14)*(r**3)
print(4/3*3.14*(r**3))
# Out:
# 904.3199999999999

# %%
print("""Que-4. Write a python program that will accept the base and height of a triangle and compute its area. Height 12 cm and base 6 cm.
Sol'n : # Formula - Area of Triangle = 1/2*(height*base) or (Height*Base)/2
          H = 12
          B = 6
          Area = (H*B)/2
          print("The area of triangle is", Area,"cm")
          --> The area of triangle is 36.0 Answer.""")
# Out:
# Que-4. Write a python program that will accept the base and height of a triangle and compute its area. Height 12 cm and base 6 cm.
# Sol'n : # Formula - Area of Triangle = 1/2*(height*base) or (Height*Base)/2
#           H = 12
#           B = 6
#           Area = (H*B)/2
#           print("The area of triangle is", Area,"cm")
#           --> The area of triangle is 36.0 Answer.

# %%
H = 12
B = 6
Area_of_triangle = (H*B)/2
print("The area of triangle is", Area_of_triangle , "cm")
# Out:
# The area of triangle is 36.0 cm

# %%
print("""Que-5. Write a python program to compute the simple interest, p=100000, r=8%, T=1 year.
Sol'n : Formula - Simple interest = (P*R*T)/100          P = Principle, R = Rate of Interest, T = Time
            P = 100000
            R = 8%
            T = 1
            Formula - Simple_interest = (P*R*T)/100
            print("The simple interest calculated is", Simple_interest.)
            --> The simple interest calculated is 8000. Answer""")
# Out:
# Que-5. Write a python program to compute the simple interest, p=100000, r=8%, T=1 year.
# Sol'n : Formula - Simple interest = (P*R*T)/100          P = Principle, R = Rate of Interest, T = Time
#             P = 100000
#             R = 8%
#             T = 1
#             Formula - Simple_interest = (P*R*T)/100
#             print("The simple interest calculated is", Simple_interest.)
#             --> The simple interest calculated is 8000. Answer

# %%
P = 100000
R = 8/100
T = 1
Simple_interest = (P*R*T)/100
print("The simple interest calculated is", Simple_interest)
# Out:
# The simple interest calculated is 80.0

# %%
print("""Que-6. Write a python program to convert the distance (in feet) to inches, yards, miles.
Sol'n : # Foot = 12 inches
          Foot = 0.33 yards
          Foot = 0.000189394 miles
          f=12
          d_inches = f*12
          d_yards = f*0.33
          d_miles = f*0.000189394
          print("The inches are",d_inches)
          print("The yards are",d_yards)
          print("The miles are",d_miles)
          --> The inches are 144
          --> The yards are 3.96
          --> The mile are 0.002272728
""")
# Out:
# Que-6. Write a python program to convert the distance (in feet) to inches, yards, miles.
# Sol'n : # Foot = 12 inches
#           Foot = 0.33 yards
#           Foot = 0.000189394 miles
#           f=12
#           d_inches = f*12
#           d_yards = f*0.33
#           d_miles = f*0.000189394
#           print("The inches are",d_inches)
#           print("The yards are",d_yards)
#           print("The miles are",d_miles)
#           --> The inches are 144
#           --> The yards are 3.96
#           --> The mile are 0.002272728

# %%
# Foot = 12 inches
# Foot = 0.33 yards
# Foot = 0.000189394 miles
f=12
d_inches = f*12
d_yards = f*0.33
d_miles = f*0.000189394
print("The inches are",d_inches)
print("The yards are",d_yards)
print("The miles are",d_miles)
# Out:
# The inches are 144
# The yards are 3.96
# The miles are 0.002272728

# %%
print("""Que-7. Write a python program to calculates the hypotenuse of a right angled triangle.
Sol'n : from math import sqrt
            base = 3
            height = 4
            hypotenuse = sqrt(base**2+height**2)
            print("The hypotenuse of the triangle is", hypotenuse)
            --> The hypotenuse of the triangle is 5.0 Answer.""")
# Out:
# Que-7. Write a python program to calculates the hypotenuse of a right angled triangle.
# Sol'n : from math import sqrt
#             base = 3
#             height = 4
#             hypotenuse = sqrt(base**2+height**2)
#             print("The hypotenuse of the triangle is", hypotenuse)
#             --> The hypotenuse of the triangle is 5.0 Answer.

# %%
from math import sqrt
base = 3
height = 4
hypotenuse = sqrt(base**2+height**2)
print("The hypotenuse of the triangle is", hypotenuse)
# Out:
# The hypotenuse of the triangle is 5.0

# %%
print("""Que-8. Write a python program to swap two variables.
Sol'n : # Python program is demonstrate.
        # Swaping of two variables.

        x=10
        y=50

        temp=x
        x==y
        y=temp

        print("Value of x :", x)
        print("Value of y :", y)

        --> Value of x = 50
        --> Value of y = 10""")
# Out:
# Que-8. Write a python program to swap two variables.
# Sol'n : # Python program is demonstrate.
#         # Swaping of two variables.
#
#         x=10
#         y=50
#
#         temp=x
#         x==y
#         y=temp
#
#         print("Value of x :", x)
#         print("Value of y :", y)
#
#         --> Value of x = 50
#         --> Value of y = 10

# %%
# Python program is demonstrate.
# Swapping of two variables.

x=10
y=50

temp=x
x==y
y==x

print("Value of x :", x)
print("Value of y :", y)
# Out:
# Value of x : 10
# Value of y : 50

# %%
print("""Que-9. Write a python programe to calculate the area of square of side 10 cm.
Sol'n : side = 10
        Area_of_squre = side*side
        print("Area of the square", Area_of_square)
        --> Area of the square 100 Answer.""")
# Out:
# Que-9. Write a python programe to calculate the area of square of side 10 cm.
# Sol'n : side = 10
#         Area_of_squre = side*side
#         print("Area of the square", Area_of_square)
#         --> Area of the square 100 Answer.

# %%
side = 25
Area_of_square = side*side
print("Area of the square is", Area_of_square)
# Out:
# Area of the square is 625

# %%
print("""Que-10. Write a python to convert 250 kg into gram.
Sol'n : kilo = 250, a = kilo*1000
        print("250 kg =" a)""")
# Out:
# Que-10. Write a python to convert 250 kg into gram.
# Sol'n : kilo = 250, a = kilo*1000
#         print("250 kg =" a)

# %%
kilo = 250
a = kilo*1000
print("250 kg = ", a, "Grams")
# Out:
# 250 kg =  250000 Grams
